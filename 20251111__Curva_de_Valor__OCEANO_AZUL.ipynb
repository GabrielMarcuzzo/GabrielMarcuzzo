# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMarcuzzo/GabrielMarcuzzo/blob/main/20251111__Curva_de_Valor__OCEANO_AZUL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Plotar uma curva de valor do Oceano Azul com Python

# PASSO 1: Importar Biblioteca
from matplotlib import pyplot as plt

# Definir o estilo de gráfico
plt.style.use("ggplot")

# Definir o eixo x do gráfico
x = ["Preço", "Disponibilidade de veiculo", "Fidelidade com Motorista", "Investimento em Marketing", "Atendimento", "Simplicidade"]

# Inserir os dados do gráfico
y1 = [6, 7, 2, 4, 7, 7]

y2 = [5, 6, 2, 5, 2, 4]

y3 = [5, 4, 6, 2, 2, 2]

y4 = [6, 5, 5, 4, 7, 5]

# Alterar a cor, o tipo e a nomenclatura das linhas do gráfico.
plt.plot(x, y1, color="k", linestyle="-", marker="o", label="Uber")
plt.plot(x, y2, color="c", linestyle="--", marker="o", linewidth=3, label="App táxi")
plt.plot(x, y3, color="y", linestyle=":", marker="o", linewidth=3, label="Taxi")
plt.plot(x, y4, color="r", linestyle="-.", marker="o", linewidth=3, label="AutoCar") # Empresa inventada

# Nomear os eixos e dar o titulo do gráfico
plt.xlabel("Atributos de Valor")
plt.title("Curva de Valor da Estratégia do Oceano Azul (Uber x App táxi x táxi x AutoCar)")

# Esconder os valores no eixo y
ax = plt.gca()
ax.axes.yaxis.set_visible(True)

# Aumentar o tamanho do grafico
plt.rcParams["figure.figsize"] = (20,6)

plt.grid(True)
plt.legend()
plt.show()
