# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMarcuzzo/GabrielMarcuzzo/blob/main/20251111__Excel__Estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PASSO 1: Importando Bibliotecas e a Planilha - 'planilha_venda_casas.xlsx'.

import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import io

from google.colab import files
uploaded = files.upload()

# %%
# PASSO 2: Estatística Descritiva

df = pd.read_excel(io.BytesIO(uploaded['planilha_venda_casas.xlsx']))
print(df)

df.info()

df = df.fillna(0)

df2 = df[["Preco", "Terreno", "Quartos", "Construcao"]]

df2.describe()

# %%
# PASSO 3: Matriz de Correlação

import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

df = pd.DataFrame(df2,columns=["Preco", "Terreno", "Quartos", "Construcao"])

corrMatrix = df.corr()
print (corrMatrix)
